# %% [markdown]
# <a href="https://colab.research.google.com/github/DuskySam2/rp_clase_patrones/blob/master/Tarea_de_E1_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Evaluación 1 - Reconocimiento de patrones**
#
# Genere las siguientes imágenes usando recorridos por píxeles a partir de la [lena.jpg](https://drive.google.com/file/d/1gH5sJN__2g7f9ndLhLvTECdOBJIGUbg_/view?usp=sharing)

# %%
# Import some libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Ejercicio 1**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-199t6nftWQoXFkp4JbVFUuHsTcedbyi/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
image = cv2.imread('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/lena.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image2 = cv2.imread('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/lena.jpg')
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera
##cambio de color y recortes
image2[0:150, 200:400, 0] = 255 #Cambia los colores del canal rojo
image2[150:300, 0:200, 2] = 255 #Cambia los colores del canal azul
image2[150:300, 200:400, 1] = 255 #Cambia los colores del canal verde
roiRojo = image2[0:150, 200:400]
roiAzul = image2[150:300, 0:200]
roiVerde = image2[150:300, 200:400]
##remplazo de cuadrantes
image[150:300, 200:400] = roiAzul
image[150:300, 0:200] = roiRojo
image[0:150, 200:400] = roiVerde
# Muestre la imagen y guardela en drive usando opencv (consultar)
plt.imshow(image)
cv2.imwrite('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/ejercicio1.jpg',image)
# Out:
# True

# %% [markdown]
# ## **Ejercicio 2**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-2ZabtbOJBg3liembLMzrwo9jWUcNdNW/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
imageOriginal = cv2.imread('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/lena.jpg')
imageOriginal = cv2.cvtColor(imageOriginal, cv2.COLOR_BGR2RGB)
imageInvertida = cv2.imread('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/lena.jpg')
# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera
imageInvertida = cv2.cvtColor(imageInvertida, cv2.COLOR_BGR2RGB)
imageInvertida = cv2.rotate(imageInvertida, cv2.ROTATE_180)
imageInvertida = cv2.flip(imageInvertida, 1)
roiInvertida = imageInvertida[150:300, 0:400]
imageOriginal[150:300,0:400] = roiInvertida
# Muestre la imagen y guardela en drive usando opencv (consultar)
plt.imshow(imageOriginal)
cv2.imwrite('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/ejercicio2.jpg',imageOriginal)
# Out:
# True

# %% [markdown]
# ## **Ejercicio 3**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-7DL7XNLoZ850EyxbjsPN40-thoOUt58/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
imageOriginal = cv2.imread('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/lena.jpg')
imageOriginal = cv2.cvtColor(imageOriginal, cv2.COLOR_BGR2RGB)
# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera
roi = imageOriginal[100:200, 0:400]
imageOriginal[0:100, 0:400] = roi
imageOriginal[200:300, 0:400] = roi 
# Muestre la imagen y guardela en drive usando opencv (consultar)
plt.imshow(imageOriginal)
cv2.imwrite('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/ejercicio3.jpg',imageOriginal)
# Out:
# True

# %% [markdown]
# ## **Ejercicio 4**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-9jWSwRb1ld_xN6iHTHVKT92bGat0I4s/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
image = cv2.imread('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/lena.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image2 = image[100:200,175:275]
# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera
i=0
j=100
while(j<=400):
  image[0:100, i:j] = image2
  i+=100
  j+=100
patron = image[0:100,0:400]
image[100:200, 0:400] = patron
image[200:300, 0:400] = patron
# Muestre la imagen y guardela en drive usando opencv (consultar)
plt.imshow(image)
cv2.imwrite('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/ejercicio4.jpg',image)
# Out:
# True

# %% [markdown]
# ## **Ejercicio 5**
#
# Genere la siguiente imagen [resultado](https://drive.google.com/file/d/1-B7q4mrI5RqLDFPm0kJS8BClpKRiCcge/view?usp=sharing). Para esto, use la imagen de [Baboon.png](https://drive.google.com/file/d/1FaFhZvB3Iom32ZP8yQIfBDnKQiKxspAz/view?usp=sharing). \\
# **NOTA:** En la salida de la celda puede encontrar el tamaño de la imagen final.

# %%
# Lea la imagen
image = cv2.imread('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/lena.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image2 = cv2.imread('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/Baboon.png')
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
# Realice aquí todas las operaciones que necesite. Puede añadir cuantas celdas de código requiera
image2 = cv2.resize(image2, (100,100))
image[100:200, 175:275] = image2
# Muestre la imagen y guardela en drive usando opencv (consultar)
print(image2.shape)
plt.imshow(image)
cv2.imwrite('/content/drive/MyDrive/Documentos UNIVERSIDAD/SEMESTRE 6/RECONOCIMIENTO DE PATRONES/repositorio/patrones/Clase3/Tarea/ejercicio5.jpg',image)
# Out:
# (100, 100, 3)
# True
